# %%
import altair as alt
import pandas as pd
import numpy as np

analysis_data = pd.read_excel("時間序列分析資料.xlsx")
analysis_data.drop("Unnamed: 0",axis=1,inplace=True)
for col,i in enumerate(analysis_data.columns):
    print(col,i)

np.random.seed(42)
source = pd.DataFrame(np.cumsum(np.random.randn(100, 3), 0).round(2),
                    columns=['A', 'B', 'C'], index=pd.RangeIndex(100, name='x'))
print(source)
source = source.reset_index().melt('x', var_name='category', value_name='y')
print(source)

# Create a selection that chooses the nearest point & selects based on x-value
nearest = alt.selection(type='single', nearest=True, on='mouseover',
                        fields=['x'], empty='none')

# The basic line
line = alt.Chart(source).mark_line(interpolate='basis').encode(
    x='x:Q',
    y='y:Q',
    color='category:N'
)

# Transparent selectors across the chart. This is what tells us
# the x-value of the cursor
selectors = alt.Chart(source).mark_point().encode(
    x='x:Q',
    opacity=alt.value(0),
).add_selection(
    nearest
)

# Draw points on the line, and highlight based on selection
points = line.mark_point().encode(
    opacity=alt.condition(nearest, alt.value(1), alt.value(0))
)

# Draw text labels near the points, and highlight based on selection
text = line.mark_text(align='left', dx=5, dy=-5).encode(
    text=alt.condition(nearest, 'y:Q', alt.value(' '))
)

# Draw a rule at the location of the selection
rules = alt.Chart(source).mark_rule(color='gray').encode(
    x='x:Q',
).transform_filter(
    nearest
)

# Put the five layers into a chart and bind the data
alt.layer(
    line, selectors, points, rules, text
).properties(
    width=600, height=300
)

alt.renderers.enable('html')
print(alt.renderers)
# Out:
# 0 BOX_OFFICE
# 1 GAME_NO
# 2 DATE
# 3 HOST_LAMIGO桃猿
# 4 HOST_中信兄弟
# 5 HOST_富邦悍將
# 6 HOST_統一7-ELEVEn獅
# 7 CLIENT_LAMIGO桃猿
# 8 CLIENT_中信兄弟
# 9 CLIENT_富邦悍將
# 10 CLIENT_統一7-ELEVEn獅
# 11 台南
# 12 嘉義市
# 13 天母
# 14 斗六
# 15 新莊
# 16 桃園
# 17 洲際
# 18 澄清湖
# 19 花蓮
# 20 Fri
# 21 Sat
# 22 Sun
# 23 Thu
# 24 Tue
# 25 Wed
# 26 氣溫(℃)
# 27 相對溼度(%)
# 28 降水量(mm)
# 29 Previous_BOX_OFFICE
# 30 Previous_HOST_LAMIGO桃猿
# 31 Previous_HOST_中信兄弟
# 32 Previous_HOST_富邦悍將
# 33 Previous_HOST_統一7-ELEVEn獅
# 34 Previous_CLIENT_LAMIGO桃猿
# 35 Previous_CLIENT_中信兄弟
# 36 Previous_CLIENT_富邦悍將
# 37 Previous_CLIENT_統一7-ELEVEn獅
# 38 Previous_台南
# 39 Previous_嘉義市
# 40 Previous_天母
# 41 Previous_斗六
# 42 Previous_新莊
# 43 Previous_桃園
# 44 Previous_洲際
# 45 Previous_澄清湖
# 46 Previous_花蓮
# 47 Previous_Fri
# 48 Previous_Sat
# 49 Previous_Sun
# 50 Previous_Thu
# 51 Previous_Tue
# 52 Previous_Wed
# 53 Previous_氣溫(℃)
# 54 Previous_相對溼度(%)
# 55 Previous_降水量(mm)
# 56 Previous_CLIENT_HR
# 57 Previous_CLIENT_ERR
# 58 Previous_HOST_HR
# 59 Previous_HOST_ERR
# 60 Previous_CLIENT_SCORE
# 61 Previous_HOST_SCORE
# 62 Previous_TIME
# 63 Previous_HOST_PA
# 64 Previous_HOST_AB
# 65 Previous_HOST_H
# 66 Previous_HOST_2B
# 67 Previous_HOST_3B
# 68 Previous_HOST_TB
# 69 Previous_HOST_SO
# 70 Previous_HOST_SB
# 71 Previous_HOST_CS_1
# 72 Previous_HOST_SAC
# 73 Previous_HOST_SF
# 74 Previous_HOST_BB
# 75 Previous_HOST_IBB
# 76 Previous_HOST_HBP
# 77 Previous_HOST_GIDP
# 78 Previous_HOST_LOB
# 79 Previous_HOST_CS_2
# 80 Previous_HOST_PB
# 81 Previous_CLIENT_PA
# 82 Previous_CLIENT_AB
# 83 Previous_CLIENT_H
# 84 Previous_CLIENT_2B
# 85 Previous_CLIENT_3B
# 86 Previous_CLIENT_TB
# 87 Previous_CLIENT_SO
# 88 Previous_CLIENT_SB
# 89 Previous_CLIENT_CS_1
# 90 Previous_CLIENT_SAC
# 91 Previous_CLIENT_SF
# 92 Previous_CLIENT_BB
# 93 Previous_CLIENT_IBB
# 94 Previous_CLIENT_HBP
# 95 Previous_CLIENT_GIDP
# 96 Previous_CLIENT_LOB
# 97 Previous_CLIENT_CS_2
# 98 Previous_CLIENT_PB
# 99 Previous_HOST_BF
# 100 Previous_HOST_NP_1
# 101 Previous_HOST_ER
# 102 Previous_HOST_AO
# 103 Previous_HOST_GO
# 104 Previous_HOST_NBB
# 105 Previous_HOST_BS
# 106 Previous_HOST_S
# 107 Previous_HOST_WP
# 108 Previous_HOST_BK
# 109 Previous_HOST_PO.1
# 110 Previous_HOST_A.1
# 111 Previous_HOST_DP.1
# 112 Previous_HOST_TP
# 113 Previous_HOST_E.1
# 114 Previous_HOST_PK
# 115 Previous_CLIENT_BF
# 116 Previous_CLIENT_NP_1
# 117 Previous_CLIENT_ER
# 118 Previous_CLIENT_AO
# 119 Previous_CLIENT_GO
# 120 Previous_CLIENT_NBB
# 121 Previous_CLIENT_BS
# 122 Previous_CLIENT_S
# 123 Previous_CLIENT_WP
# 124 Previous_CLIENT_BK
# 125 Previous_CLIENT_PO.1
# 126 Previous_CLIENT_A.1
# 127 Previous_CLIENT_DP.1
# 128 Previous_CLIENT_TP
# 129 Previous_CLIENT_E.1
# 130 Previous_CLIENT_PK
#        A      B     C
# x
# 0   0.50  -0.14  0.65
# 1   2.02  -0.37  0.41
# 2   3.60   0.40 -0.06
# 3   4.14  -0.07 -0.52
# 4   4.38  -1.98 -2.25
# ..   ...    ...   ...
# 95  8.72 -17.23  5.31
# 96  9.01 -17.85  5.10
# 97  8.51 -18.44  5.95
# 98  8.87 -19.14  6.85
# 99  9.18 -18.32  7.48
#
# [100 rows x 3 columns]
#       x category     y
# 0     0        A  0.50
# 1     1        A  2.02
# 2     2        A  3.60
# 3     3        A  4.14
# 4     4        A  4.38
# ..   ..      ...   ...
# 295  95        C  5.31
# 296  96        C  5.10
# 297  97        C  5.95
# 298  98        C  6.85
# 299  99        C  7.48
#
# [300 rows x 3 columns]
# RendererRegistry(active='html', registered=['altair_viewer', 'colab', 'default', 'html', 'json', 'jupyterlab', 'kaggle', 'mimetype', 'nteract', 'png', 'svg', 'zeppelin'])
